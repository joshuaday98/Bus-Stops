# %%
import pandas as pd

# %%
df = pd.read_csv('../bus_stop/data/stops-manhattan.txt')

# %%
df
# Out:
#       stop_id                                  stop_name  stop_desc  \
# 0      400001                                4 AV/E 9 ST        NaN
# 1      400002                               4 AV/E 12 ST        NaN
# 2      400003                               4 AV/E 13 ST        NaN
# 3      400007                          PARK AV S/E 21 ST        NaN
# 4      400026                         MADISON AV/E 63 ST        NaN
# 5      400027                         MADISON AV/E 65 ST        NaN
# 6      400028                         MADISON AV/E 67 ST        NaN
# 7      400029                         MADISON AV/E 69 ST        NaN
# 8      400030                         MADISON AV/E 72 ST        NaN
# 9      400032                         MADISON AV/E 77 ST        NaN
# 10     400033                         MADISON AV/E 79 ST        NaN
# 11     400034                         MADISON AV/E 83 ST        NaN
# 12     400036                         MADISON AV/E 86 ST        NaN
# ...
